# %%
import numpy as np 
import pandas as pd
import matplotlib as mlp
import matplotlib.pyplot as plt
import os

# %%
#df_carbon_tax = pd.read_csv('../data/Carbon_Tax_Pricing/CPI_Data_DashboardExtract.csv')
df_emm = pd.read_csv('../data/historical_emissions/historical_emissions.csv')

# %%
df_emm.head()
# Out:
#   Country Data source                Sector      Gas    Unit      2017  \
# 0   World        CAIT  Total including LUCF  All GHG  MtCO₂e  49947.42
# 1   World        CAIT  Total excluding LUCF  All GHG  MtCO₂e  46730.35
# 2   World        CAIT                Energy  All GHG  MtCO₂e  36435.64
# 3   World        CAIT      Electricity/Heat  All GHG  MtCO₂e  15167.36
# 4   China        CAIT  Total excluding LUCF  All GHG  MtCO₂e  12090.97
#
#        2016      2015      2014      2013  ...      1999      1998      1997  \
# 0  49312.19  49828.88  49494.56  49037.46  ...  36817.13  36981.63  37338.36
# 1  46095.12  45916.49  45917.75  45670.78  ...  33119.37  32910.54  32700.50
# 2  35970.69  35951.84  36053.93  35997.40  ...  25236.65  25085.99  24925.72
# 3  14949.51  15009.83  15232.52  15320.55  ...  10134.66  10080.66   9853.19
# 4  11887.96  11888.02  11890.44  11878.47  ...   4399.54   4449.07   4309.89
#
#        1996      1995      1994      1993      1992      1991      1990
# ...

# %%
df_emm1 = df_emm.sort_values('Country', ascending=True)
df_emm2 = df_emm.sort_values('Sector', ascending=True)

# %%
fig=plt.figure(figsize=(20,5))

ax1 = fig.add_subplot(1,2,1)
#ax2 = fig.add_subplot(1,2,2)

ax1.bar(df_emm1.index, df_emm1['Country'])
ax1.set_xticklabels(df_emm1.index, rotation=50, horizontalalignment='right', fontsize='12')

ax1.set_title("Country Emissions", fontsize=30)
ax1.set_ylabel("# Emmissions")

plt.show()

# %% [markdown]
# df_emm3 = df_emm.groupby('Country').groups
# print(df_emm3)

# %% [markdown]
# df_emm4 = df_emm.groupby('Sector').groups
# print(df_emm4)

# %% [markdown]
# df_emm5 = df_emm.groupby(['Sector','Country']).groups
# print(df_emm5)

# %% [markdown]
# df_emm6 = df_emm.groupby(['Sector','2017']).groups
# print(df_emm6)
# score = lambda x : (x-x.mean()) / x.std()*10
# print(grouped.transform(score))

# %%
df_7_group = df_emm.groupby("Sector")
score = score = lambda x : (x-x.mean()) / x.std()*10 
print(df_7_group.transform(score))
# Out:
#             2017        2016        2015        2014        2013        2012  \
# 0     132.848857  133.538827  133.553258  133.444757  133.422859  133.584676
# 1     131.963181  132.633162  132.559571  132.520500  132.467357  132.642762
# 2     131.148443  131.831070  131.742366  131.728432  131.649832  131.831381
# 3     129.141105  129.495431  129.562735  129.478203  129.305450  129.679100
# 4      33.096627   33.162320   33.277929   33.275180   33.411942   32.602198
# ...          ...         ...         ...         ...         ...         ...
# 2703         NaN         NaN         NaN   -1.388214   -1.390285   -1.392527
# 2704         NaN         NaN         NaN   -1.388214   -1.390285   -1.392527
# 2705         NaN         NaN         NaN   -1.388214   -1.390285   -1.392527
# 2706         NaN         NaN         NaN   -1.388214   -1.390285   -1.392527
# 2707         NaN         NaN         NaN   -1.388214   -1.390285   -1.392527
#
# ...

# %%
df_7_group = df_emm.groupby("Country")
score = score = lambda x : (x-x.mean()) / x.std()*10 
print(df_7_group.transform(score))
# Out:
#            2017       2016       2015       2014       2013       2012  \
# 0     20.996037  21.007436  21.227183  21.084122  20.984314  21.052576
# 1     19.160561  19.147578  18.970163  19.018209  19.029215  19.010754
# 2     13.286988  13.294426  13.221652  13.321012  13.411689  13.344866
# 3      1.152523   1.141628   1.140406   1.294874   1.404227   1.371212
# 4     19.317964  19.365591  19.334923  19.311399  19.242040  19.267903
# ...         ...        ...        ...        ...        ...        ...
# 2703        NaN        NaN        NaN  -7.064938  -6.985849  -7.128972
# 2704        NaN        NaN        NaN  -6.912458  -6.874380  -6.845934
# 2705        NaN        NaN        NaN  -7.971605  -7.802979  -7.623108
# 2706        NaN        NaN        NaN  -8.112787  -8.233709  -8.486667
# 2707        NaN        NaN        NaN  -7.029794  -7.027523  -7.042244
#
#            2011       2010       2009       2008  ...       1999       1998  \
# ...

# %% [markdown]
# for sec, group in df_emm5:
#     print(sec)
#     print(group)
